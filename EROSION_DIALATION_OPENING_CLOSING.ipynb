# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
from matplotlib import pyplot as plt

# %%
img1 = cv2.imread('hello.jpg') 
img_gray=cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
ret, bw_img = cv2.threshold(img_gray,127,255,cv2.THRESH_BINARY)
kernel = np.ones((7,7), np.uint8) 
img_erosion = cv2.erode(bw_img, kernel, iterations=1) 
img_dilation = cv2.dilate(bw_img, kernel, iterations=1)
img_opening = cv2.dilate(img_erosion, kernel, iterations=1)
img_closing = cv2.erode(img_dialation, kernel, iterations=1)

# %%
cv2_imshow(img1) 
cv2_imshow(img_gray)
cv2_imshow(bw_img)
cv2_imshow(img_erosion) 
cv2_imshow( img_dilation) 
cv2_imshow(img_opening) 
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=478x607 at 0x7F3993ED20F0>
# <PIL.Image.Image image mode=L size=478x607 at 0x7F3993ED20B8>
# <PIL.Image.Image image mode=L size=478x607 at 0x7F3993ED21D0>
# <PIL.Image.Image image mode=L size=478x607 at 0x7F3993ED2048>
# <PIL.Image.Image image mode=L size=478x607 at 0x7F3993ED2128>
# <PIL.Image.Image image mode=L size=478x607 at 0x7F3993ED20F0>
# -1
