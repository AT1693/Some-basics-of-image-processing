# %%
import math
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('download.jpg')
img_log = (np.log(img+1)/(np.log(1+np.max(img))))*255
img_log = np.array(img_log,dtype=np.uint8)

# %%
cv2_imshow(img)
cv2_imshow(img_log)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F0F5E063C88>
# <PIL.Image.Image image mode=RGB size=225x225 at 0x7F0F5E063C18>

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-3694b9167aa4> in <module>()
# ----> 1 img_log = (np.antilog(img+1)/(np.antilog(1+np.max(img))))*255
#       2 img_log = np.array(img_log,dtype=np.uint8)
#
# AttributeError: module 'numpy' has no attribute 'antilog'
