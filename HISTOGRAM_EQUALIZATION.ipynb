# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
from matplotlib import pyplot as plt

# %%
img1= cv2.imread('download.jfif')
img2=cv2.cvtColor(img1, cv2.COLOR_BGR2GRAY)
hist,bins = np.histogram(img2.flatten(),256,[0,256])
cdf = hist.cumsum()

# %%
plt.plot(cdf_normalized, color = 'b')
plt.hist(img2.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()

# %%
img3 = cv2.equalizeHist(img2)
cv2_imshow(img2)
cv2_imshow(img3)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=225x224 at 0x7F27216C1C50>
# <PIL.Image.Image image mode=L size=225x224 at 0x7F2724348DD8>
# -1

# %%
plt.plot(cdf_normalized, color = 'b')
plt.hist(img3.flatten(),256,[0,256], color = 'r')
plt.xlim([0,256])
plt.legend(('cdf','histogram'), loc = 'upper left')
plt.show()
